# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusMGL/CurriculoHTML/blob/main/exerc%C3%ADcios_anatel_mg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![anatel](img/anatel_logo.png "Logo Anatel")
#
# # Análise de Dados da Anatel em Minas Gerais (2006 - 2019)

# %% [markdown]
# A Agência Nacional de Telecomunicaçõe ([Anatel](https://www.anatel.gov.br/institucional/)) foi criada em 16 de julho de 1997 com o objetivo de regular o setor de telecomunicações para contribuir com o desenvolvimento do Brasil. Neste estudo iremos explorar o conjunto de dados das **Reclamações Registradas na Anatel** no estado de Minas Gerais durante os anos de 2006 até 2019. Os dados foram baixaados do  website [Dados Abertos](http://www.dados.gov.br/dataset/solicitacoesregistradasnaanatel) e o [Dicionário de Dados Oficial](data/Reclamações_Glossário_e_Metadados.pdf) está disponível na pasta: [`data/Reclamações_Glossário_e_Metadados.pdf`](data/Reclamações_Glossário_e_Metadados.pdf).

# %% [markdown]
# ## Exercícios
# Faça as questões abaixo usando somente a biblioteca [pandas](https://pandas.pydata.org/).

# %% [markdown]
# 1. Importe o pacote **pandas** como o nome pd.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 2. Carregue em memória o conjunto de dados disponível na pasta [`data/anatel_mg_2006_2019.csv`](data/anatel_mg_2006_2019.csv) para uma variável chamada **df**.

# %%
df = pd.read_csv('anatel_mg_2006_2019.csv')

# %% [markdown]
# 3. Quantas linhas e quantas colunas foram carregadas em memória?

# %%
df.shape
# Out:
# (17819, 12)

# %% [markdown]
# 4. Mostre as 5 primeiras linhas do *dataset*.

# %%
df[:5]
# Out:
#   DataExtracao   Ano  Mes          CanalEntrada Condicao GrupoEconNorm  \
# 0   2016-04-28  2006    1  Atendimento Pessoal      Nova        Anatel
# 1   2016-04-28  2006    1  Atendimento Pessoal      Nova        Anatel
# 2   2016-04-28  2006    1  Atendimento Pessoal      Nova           NET
# 3   2016-04-28  2006    1  Atendimento Pessoal      Nova            OI
# 4   2016-04-28  2006    1  Atendimento Pessoal      Nova        Outros
#
#          Tipo                                  Servico Modalidade  \
# 0    Denúncia                Radiodifusão (Rádio e TV)   Rádio FM
# 1    Denúncia                Radiodifusão (Rádio e TV)   Rádio FM
# 2  Reclamação  Serviço Telefônico Fixo Comutado - STFC      Local
# 3  Reclamação                            Móvel Pessoal   Pós-Pago
# 4  Reclamação                            Móvel Pessoal   Pós-Pago
#
#                 Motivo  UF  QtdeSolic
# 0        Interferência  MG        3.0
# 1              Outorga  MG        8.0
# 2             Cobrança  MG        1.0
# 3  Serviços Adicionais  MG        1.0
# 4             Clonagem  MG        1.0

# %% [markdown]
# 5.  Quais são os tipos de dados de cada uma das colunas?

# %%
df.dtypes
# Out:
# DataExtracao      object
# Ano                int64
# Mes                int64
# CanalEntrada      object
# Condicao          object
# GrupoEconNorm     object
# Tipo              object
# Servico           object
# Modalidade        object
# Motivo            object
# UF                object
# QtdeSolic        float64
# dtype: object

# %% [markdown]
# 6. Mostre a quantidade de colunas para cada um dos tipos de dados.

# %%
df.dtypes.value_counts()
# Out:
# object     9
# int64      2
# float64    1
# dtype: int64

# %% [markdown]
# 7. Mostre as informações básicas do DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17819 entries, 0 to 17818
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DataExtracao   17819 non-null  object
#  1   Ano            17819 non-null  int64
#  2   Mes            17819 non-null  int64
#  3   CanalEntrada   17819 non-null  object
#  4   Condicao       17819 non-null  object
#  5   GrupoEconNorm  17819 non-null  object
#  6   Tipo           17818 non-null  object
#  7   Servico        17818 non-null  object
#  8   Modalidade     17818 non-null  object
#  9   Motivo         17818 non-null  object
#  10  UF             17818 non-null  object
#  11  QtdeSolic      17818 non-null  float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 1.6+ MB

# %% [markdown]
# 8. Verifique se existem dados ausentes (*misssing data*) no conjunto de dados.

# %%
df.isnull().values.any()
# Out:
# True

# %% [markdown]
# 9. Qual é o número total de dados ausentes?

# %%
df.isnull().sum().sum()
# Out:
# 6

# %% [markdown]
# 10. Qual é o número total de dados ausentes por coluna?

# %%
df.isnull().sum()
# Out:
# DataExtracao     0
# Ano              0
# Mes              0
# CanalEntrada     0
# Condicao         0
# GrupoEconNorm    0
# Tipo             1
# Servico          1
# Modalidade       1
# Motivo           1
# UF               1
# QtdeSolic        1
# dtype: int64

# %% [markdown]
# 11. Remova todos os dados ausentes encontrados.

# %%
df.dropna(subset=['GrupoEconNorm'], inplace=True)

# %% [markdown]
# 12. Selecione o serviço que possui o maior número de solicitações `QtdeSolic` na Anatel.

# %%
df.loc[df.QtdeSolic == np.max(df.QtdeSolic), ['Servico']]
# Out:
#                                        Servico
# 11294  Serviço Telefônico Fixo Comutado - STFC

# %% [markdown]
# 13. Qual é o menor número de solicitações `QtdeSolic` na Anatel.

# %%
df.QtdeSolic.min()
# Out:
# 1.0

# %% [markdown]
# 14. Mostre todas as linhs iguais ao menor número de solicitações `QtdeSolic` na Anatel.

# %%
df.loc[df.QtdeSolic == np.min(df.QtdeSolic)]
# Out:
#       DataExtracao   Ano  Mes          CanalEntrada       Condicao  \
# 2       2016-04-28  2006    1  Atendimento Pessoal            Nova
# 3       2016-04-28  2006    1  Atendimento Pessoal            Nova
# 4       2016-04-28  2006    1  Atendimento Pessoal            Nova
# 5       2016-04-28  2006    1  Atendimento Pessoal        Reaberta
# 6       2016-04-28  2006    1  Atendimento Pessoal        Reaberta
# ...            ...   ...  ...                   ...            ...
# 17806   2016-04-28  2007    8           Call Center  Reencaminhada
# 17807   2016-04-28  2007    8           Call Center  Reencaminhada
# 17808   2016-04-28  2007    8           Call Center  Reencaminhada
# 17815   2016-04-28  2007    8           Call Center  Reencaminhada
# 17816   2016-04-28  2007    8           Call Center  Reencaminhada
#
#       GrupoEconNorm        Tipo                                  Servico  \
# 2               NET  Reclamação  Serviço Telefônico Fixo Comutado - STFC
# 3                OI  Reclamação                            Móvel Pessoal
# 4            Outros  Reclamação                            Móvel Pessoal
# 5               NET  Reclamação  Serviço Telefônico Fixo Comutado - STFC
# 6            Outros  Reclamação  Serviço Telefônico Fixo Comutado - STFC
# ...             ...         ...                                      ...
# 17806          BLUE  Reclamação                        TV por Assinatura
# 17807          BLUE  Reclamação                        TV por Assinatura
# 17808         CLARO  Reclamação                            Móvel Pessoal
# 17815           NET  Reclamação                        TV por Assinatura
# 17816           NET  Reclamação                        TV por Assinatura
#
#       Modalidade                            Motivo  UF  QtdeSolic
# 2          Local                          Cobrança  MG        1.0
# 3       Pós-Pago               Serviços Adicionais  MG        1.0
# 4       Pós-Pago                          Clonagem  MG        1.0
# 5          Local                            Reparo  MG        1.0
# 6          Local                      Cancelamento  MG        1.0
# ...          ...                               ...  ..        ...
# 17806  TV a Cabo                      Cancelamento  MG        1.0
# 17807  TV a Cabo               Mudança de endereço  MG        1.0
# 17808   Pré-Pago                   Cartão pré-pago  MG        1.0
# 17815  TV a Cabo  Contrato de prestação de serviço  MG        1.0
# 17816  TV a Cabo                       Equipamento  MG        1.0
#
# [9159 rows x 12 columns]

# %% [markdown]
# 15. Mostre as contagens de solicitações `QtdeSolic` por tipo de serviço `Servico`.

# %%
pd.crosstab(df['QtdeSolic'],df['Servico'])
# Out:
# Servico    Limitado Privado  Móvel Pessoal  Outros  Radioamador (PY)  \
# QtdeSolic
# 1.0                      95           3815      63                98
# 2.0                      19           1284      16                17
# 3.0                       7            683       8                 5
# 4.0                       3            419       2                 7
# 5.0                       1            296       1                 4
# ...                     ...            ...     ...               ...
# 399.0                     0              1       0                 0
# 404.0                     0              1       0                 0
# 412.0                     0              1       0                 0
# 415.0                     0              1       0                 0
# 454.0                     0              0       0                 0
#
# Servico    Radiochamada (Paging)  Radiodifusão (Rádio e TV)  \
# QtdeSolic
# 1.0                            3                        326
# 2.0                            0                         79
# 3.0                            0                         36
# 4.0                            0                         17
# 5.0                            0                         11
# ...                          ...                        ...
# 399.0                          0                          0
# 404.0                          0                          0
# 412.0                          0                          0
# 415.0                          0                          0
# 454.0                          0                          0
#
# Servico    Rádio do Cidadão (PX)  Serviço Móvel Aeronáutico  \
# QtdeSolic
# 1.0                           83                          3
# 2.0                           13                          0
# 3.0                            4                          0
# 4.0                            0                          0
# 5.0                            0                          0
# ...                          ...                        ...
# 399.0                          0                          0
# 404.0                          0                          0
# 412.0                          0                          0
# 415.0                          0                          0
# 454.0                          0                          0
#
# Servico    Serviço Móvel Marítimo  Serviço Telefônico Fixo Comutado - STFC  \
# QtdeSolic
# 1.0                             2                                     2602
# 2.0                             0                                      784
# 3.0                             0                                      392
# 4.0                             0                                      270
# 5.0                             0                                      184
# ...                           ...                                      ...
# 399.0                           0                                        0
# 404.0                           0                                        0
# 412.0                           0                                        1
# 415.0                           0                                        0
# 454.0                           0                                        1
#
# Servico    Serviço de Comunicação Multimídia  \
# QtdeSolic
# 1.0                                      614
# 2.0                                      124
# 3.0                                       63
# 4.0                                       39
# 5.0                                       25
# ...                                      ...
# 399.0                                      0
# 404.0                                      0
# 412.0                                      0
# 415.0                                      0
# 454.0                                      0
#
# Servico    Serviço de Rede e Transporte de Telecomunicações - SRTT  \
# QtdeSolic
# 1.0                                                      284
# 2.0                                                       71
# 3.0                                                       40
# 4.0                                                       31
# 5.0                                                       14
# ...                                                      ...
# 399.0                                                      0
# 404.0                                                      0
# 412.0                                                      0
# 415.0                                                      0
# 454.0                                                      0
#
# Servico    Serviços da Anatel  TV por Assinatura  Troncalizado (Trunking)
# QtdeSolic
# 1.0                       381                769                       21
# 2.0                        58                139                        5
# 3.0                        41                 66                        0
# 4.0                        22                 24                        1
# 5.0                        12                 30                        0
# ...                       ...                ...                      ...
# 399.0                       0                  0                        0
# 404.0                       0                  0                        0
# 412.0                       0                  0                        0
# 415.0                       0                  0                        0
# 454.0                       0                  0                        0
#
# [224 rows x 15 columns]

# %% [markdown]
# 16. Ao longo dos anos mostre o número de solicitações por mês?

# %%
df[['Ano', 'QtdeSolic', 'Mes']].groupby(['QtdeSolic', 'Mes']).mean()
# Out:
#                        Ano
# QtdeSolic Mes
# 1.0       1    2006.530318
#           2    2006.496842
#           3    2006.513744
#           4    2006.518750
#           5    2006.515068
# ...                    ...
# 399.0     5    2007.000000
# 404.0     8    2007.000000
# 412.0     6    2007.000000
# 415.0     3    2007.000000
# 454.0     1    2007.000000
#
# [923 rows x 1 columns]

# %% [markdown]
# 17. Crie o vetor **reclamacoes** com todos os dados que cuja coluna `Tipo` seja igual a "Reclamação".

# %%
reclamacoes = df[df.Tipo == "Reclamação"]
reclamacoes
# Out:
#       DataExtracao   Ano  Mes          CanalEntrada       Condicao  \
# 2       2016-04-28  2006    1  Atendimento Pessoal            Nova
# 3       2016-04-28  2006    1  Atendimento Pessoal            Nova
# 4       2016-04-28  2006    1  Atendimento Pessoal            Nova
# 5       2016-04-28  2006    1  Atendimento Pessoal        Reaberta
# 6       2016-04-28  2006    1  Atendimento Pessoal        Reaberta
# ...            ...   ...  ...                   ...            ...
# 17813   2016-04-28  2007    8           Call Center  Reencaminhada
# 17814   2016-04-28  2007    8           Call Center  Reencaminhada
# 17815   2016-04-28  2007    8           Call Center  Reencaminhada
# 17816   2016-04-28  2007    8           Call Center  Reencaminhada
# 17817   2016-04-28  2007    8           Call Center  Reencaminhada
#
#       GrupoEconNorm        Tipo                                  Servico  \
# 2               NET  Reclamação  Serviço Telefônico Fixo Comutado - STFC
# 3                OI  Reclamação                            Móvel Pessoal
# 4            Outros  Reclamação                            Móvel Pessoal
# 5               NET  Reclamação  Serviço Telefônico Fixo Comutado - STFC
# 6            Outros  Reclamação  Serviço Telefônico Fixo Comutado - STFC
# ...             ...         ...                                      ...
# 17813           NET  Reclamação                        TV por Assinatura
# 17814           NET  Reclamação                        TV por Assinatura
# 17815           NET  Reclamação                        TV por Assinatura
# 17816           NET  Reclamação                        TV por Assinatura
# 17817           NET  Reclamação                        TV por Assinatura
#
#       Modalidade                            Motivo  UF  QtdeSolic
# 2          Local                          Cobrança  MG        1.0
# 3       Pós-Pago               Serviços Adicionais  MG        1.0
# 4       Pós-Pago                          Clonagem  MG        1.0
# 5          Local                            Reparo  MG        1.0
# 6          Local                      Cancelamento  MG        1.0
# ...          ...                               ...  ..        ...
# 17813  TV a Cabo                          Bloqueio  MG        5.0
# 17814  TV a Cabo                          Cobrança  MG       23.0
# 17815  TV a Cabo  Contrato de prestação de serviço  MG        1.0
# 17816  TV a Cabo                       Equipamento  MG        1.0
# 17817  TV a Cabo                        Instalação  MG        7.0
#
# [13987 rows x 12 columns]

# %% [markdown]
# 18. Mostre o número total de solictiações `QtdeSolic` de reclamações para cada tipo de serviço `Servico`

# %%
df.groupby('Servico').QtdeSolic.count()
# Out:
# Servico
# Limitado Privado                                            135
# Móvel Pessoal                                              8406
# Outros                                                       90
# Radioamador (PY)                                            136
# Radiochamada (Paging)                                         3
# Radiodifusão (Rádio e TV)                                   518
# Rádio do Cidadão (PX)                                       101
# Serviço Móvel Aeronáutico                                     3
# Serviço Móvel Marítimo                                        2
# Serviço Telefônico Fixo Comutado - STFC                    5168
# Serviço de Comunicação Multimídia                          1003
# Serviço de Rede e Transporte de Telecomunicações - SRTT     531
# Serviços da Anatel                                          601
# TV por Assinatura                                          1094
# Troncalizado (Trunking)                                      27
# Name: QtdeSolic, dtype: int64

# %% [markdown]
# 19. Quais são os maiores ou maior motivo de solicitação de reclamações?

# %%
df['Motivo'].value_counts()
# Out:
# Cobrança                   2709
# Atendimento                1542
# Reparo                     1101
# Cancelamento               1034
# Bloqueio                    931
#                            ...
# Plano Básico de TV            1
# Laboratórios de Ensaios       1
# Cópia                         1
# Plano Básico de Rádio         1
# Funttel                       1
# Name: Motivo, Length: 83, dtype: int64

# %% [markdown]
# 20. Faça um agrupamento de dados pela coluna `GrupoEconNorm`, mostrando um sumário estatístico da quantidade solicitações `QtdeSolic`.

# %%
df.groupby('GrupoEconNorm').QtdeSolic.describe()
# Out:
#                 count       mean        std  min  25%  50%   75%    max
# GrupoEconNorm
# ALGAR          1469.0   3.101430   5.449039  1.0  1.0  1.0  3.00   62.0
# Anatel         3707.0   2.417588   4.270899  1.0  1.0  1.0  2.00   73.0
# BLUE             95.0   1.263158   0.639324  1.0  1.0  1.0  1.00    5.0
# CLARO          1117.0   4.848702   9.788326  1.0  1.0  2.0  4.00  124.0
# EMBRATEL        148.0   1.270270   0.705610  1.0  1.0  1.0  1.00    5.0
# GVT              38.0   1.052632   0.226294  1.0  1.0  1.0  1.00    2.0
# Intelig         139.0   1.525180   0.942791  1.0  1.0  1.0  2.00    6.0
# N                 0.0        NaN        NaN  NaN  NaN  NaN   NaN    NaN
# NET            1447.0   6.255701  16.258361  1.0  1.0  2.0  5.00  224.0
# NEXTEL           24.0   1.333333   0.701964  1.0  1.0  1.0  1.25    4.0
# OI             4716.0  10.551739  30.759231  1.0  1.0  2.0  5.00  454.0
# Outros         1741.0   7.344630  18.568934  1.0  1.0  2.0  5.00  226.0
# SKY             255.0   1.807843   1.886112  1.0  1.0  1.0  2.00   15.0
# TIM            2130.0  14.420188  40.149386  1.0  1.0  2.0  8.00  415.0
# VIVO            792.0   2.170455   2.696157  1.0  1.0  1.0  2.00   24.0
